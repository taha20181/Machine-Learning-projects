# %% [markdown]
# # Prediction Using Supervised Learning - Student Score Dataset
#
# Task #1 => Data Science & Business Analytics Tasks
#
# By: **Taha Bohra**

# %%
# Importing required libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Reading the dataset

dataset = pd.read_csv("https://raw.githubusercontent.com/AdiPersonalWorks/Random/master/student_scores%20-%20student_scores.csv")

print("Data Imported successfully")

dataset.describe
# Out:
# Data Imported successfully
# <bound method NDFrame.describe of     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86>

# %%
# Plotting the dataset visually using matplotlib
# for better understanding

dataset.plot(x='Hours', y='Scores', style='x')

plt.title("Hours vs Percentage")
plt.xlabel("Hours Studied")
plt.ylabel("Percentage")

plt.show()

# %%
# Defining the features and the value to be predicted

X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, 1].values

print(X, y)
# Out:
# [[2.5]
#  [5.1]
#  [3.2]
#  [8.5]
#  [3.5]
#  [1.5]
#  [9.2]
#  [5.5]
#  [8.3]
#  [2.7]
#  [7.7]
#  [5.9]
#  [4.5]
#  [3.3]
#  [1.1]
#  [8.9]
#  [2.5]
#  [1.9]
#  [6.1]
#  [7.4]
#  [2.7]
#  [4.8]
#  [3.8]
#  [6.9]
#  [7.8]] [21 47 27 75 30 20 88 60 81 25 85 62 41 42 17 95 30 24 67 69 30 54 35 76
#  86]

# %%
# Splitting the dataset into test and train
# ratio as 8:2
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# Now lets select a model to fit our data
from sklearn.linear_model import LogisticRegression

model = LinearRegression()

model.fit(X_train, y_train)
print("Model Training Completed")
# Out:
# Model Training Completed

# %%
# Plotting the regression line

line = model.coef_*X+model.intercept_

# Plotting for the test data

plt.scatter(X, y)
plt.plot(X, line)
plt.show()

# %%
# Now lets predict the score
print(X_test)
prediction = model.predict(X_test)
# Out:
# [[1.5]
#  [3.2]
#  [7.4]
#  [2.5]
#  [5.9]]

# %%
# Finding mean absolute error
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(prediction, y_test)
mae
# Out:
# 4.183859899002982

# %%
# comparing Actual vs Predicted

compare = pd.DataFrame({'Actual': y_test, 'Predicted': prediction})
compare
# Out:
#    Actual  Predicted
# 0      20  16.884145
# 1      27  33.732261
# 2      69  75.357018
# 3      30  26.794801
# 4      62  60.491033

# %%
# Lets test with some new data
hours = [[5.2]]
new_pred = model.predict(hours)


print("No of Hours = {}".format(hours))
print("Predicted Score = {}".format(new_pred[0]))
# Out:
# No of Hours = [[5.2]]
# Predicted Score = 53.55357374077431
